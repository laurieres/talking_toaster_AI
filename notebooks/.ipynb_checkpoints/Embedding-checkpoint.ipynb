# %%
# !pip install langchain
# Out:
# ...
#   Using cached typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.0/397.0 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.6 MB/s eta 0:00:00
# Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
# ...

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 10.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.6/277.6 kB 4.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("/Users/arnauddevoghel/code/arnaud2vo/talking_toaster_AI/datasets/manuals/fridge.pdf")
data = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=400)
texts = text_splitter.split_documents(data)

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(openai_api_key = "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")

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
# ...
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached googleapis_common_protos-1.61.0-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.4/502.4 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.3/528.3 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 8.6 MB/s eta 0:00:0000:0100:01m
# ...

# %%
# !pip install tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.5/953.5 kB 9.4 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
vector_db = Chroma.from_documents(texts, embeddings)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/arnauddevoghel/.pyenv/versions/3.10.6/envs/talking_toaster_AI/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dy/fz7t8d6n03q0rfhj0lz4tw5m0000gn/T/ipykernel_89717/4048144755.py", line 1, in <module>
#     vector_db = Chroma.from_documents(texts, embeddings)
#   File "/Users/arnauddevoghel/.pyenv/versions/3.10.6/envs/talking_toaster_AI/lib/python3.10/site-packages/langchain/vectorstores/chroma.py", line 771, in from_documents
#     return cls.from_texts(
#   File "/Users/arnauddevoghel/.pyenv/versions/3.10.6/envs/talking_toaster_AI/lib/python3.10/site-packages/langchain/vectorstores/chroma.py", line 729, in from_texts
#     chroma_collection.add_texts(
# ...

# %%
vector_db
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/arnauddevoghel/.pyenv/versions/3.10.6/envs/talking_toaster_AI/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dy/fz7t8d6n03q0rfhj0lz4tw5m0000gn/T/ipykernel_89717/552764174.py", line 1, in <module>
#     vector_db
# NameError: name 'vector_db' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/arnauddevoghel/.pyenv/versions/3.10.6/envs/talking_toaster_AI/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
# ...
